# %%
import pandas as pd
import os

# %%
dogs=pd.read_csv("C://Users//pks//Desktop//NUCHI201908DATA2//project_3//PS//CSV/nyc_dog_cleaned.csv")

# %%
dogs.head()
# Out:
#   RowNumber AnimalName AnimalGender AnimalBirthMonth  \
# 0   122,152    CHARRIE            F         8/1/2007
# 1   122,153      CHICO            M         7/1/2011
# 2   122,154       HUGO            M         7/1/2008
# 3   122,155        IKE            M         1/1/2007
# 4   122,156      JACKI            F         2/1/2008
#
#                               BreedName    Borough  ZipCode  \
# 0                               Unknown  Manhattan  10029.0
# 1                               Unknown   Brooklyn  11201.0
# 2                      Brussels Griffon     Queens  11375.0
# 3  American Pit Bull Mix / Pit Bull Mix   Brooklyn  11221.0
# 4                    Miniature Pinscher     Queens  11415.0
#
#    CommunityDistrict  CensusTract2010   NTA  CityCouncilDistrict  \
# 0              111.0            164.0  MN33                  8.0
# 1              306.0             69.0  BK38                 33.0
# 2              406.0            741.0  QN17                 29.0
# ...

# %%
dogs.shape
# Out:
# (107658, 15)

# %%
# Find which breed has highest number of dogs and out of which how many are males and females.

# %%
dogs['BreedName'].value_counts()
# Out:
# Unknown                                 16284
# Yorkshire Terrier                        7257
# Shih Tzu                                 6763
# Chihuahua                                5483
# Labrador Retriever                       4101
# Maltese                                  4028
# American Pit Bull Mix / Pit Bull Mix     3339
# American Pit Bull Terrier/Pit Bull       3307
# Labrador Retriever Crossbreed            2715
# Beagle                                   2004
# Pomeranian                               2003
# Jack Russell Terrier                     1956
# Golden Retriever                         1893
# Havanese                                 1882
# German Shepherd Dog                      1843
# Cocker Spaniel                           1738
# Pug                                      1507
# German Shepherd Crossbreed               1423
# Cavalier King Charles Spaniel            1375
# Shiba Inu                                1198
# ...

# %%
dogs_yorkshire=dogs[dogs.BreedName == "Yorkshire Terrier"] # df[df.B == 9]

# %%
dogs_yorkshire.head()
# Out:
#    RowNumber AnimalName AnimalGender AnimalBirthMonth          BreedName  \
# 13   122,166     SASSYS            F        11/1/2007  Yorkshire Terrier
# 15   122,168    BISCUIT            M        12/1/2015  Yorkshire Terrier
# 28   122,185     POOCHY            M        12/1/2009  Yorkshire Terrier
# 32   122,189   CAPELLAN            M        10/1/2016  Yorkshire Terrier
# 39   122,197     AFRICA            F         4/1/2009  Yorkshire Terrier
#
#           Borough  ZipCode  CommunityDistrict  CensusTract2010   NTA  \
# 13          Bronx  10455.0              201.0             79.0  BX34
# 15      Manhattan  10002.0              103.0            202.0  MN28
# 28          Bronx  10455.0              201.0             79.0  BX34
# 32  Staten Island  10303.0              501.0          31902.0  SI12
# 39          Bronx  10455.0              201.0             79.0  BX34
#
#     CityCouncilDistrict  CongressionalDistrict  StateSenatorialDistrict  \
# ...

# %%
dogs_yorkshire['AnimalGender'].value_counts()
# Out:
# M    4095
# F    3161
#         1
# Name: AnimalGender, dtype: int64

# %%
# Over all How many male and female dogs are registered.

# %%
dogs.head()
# Out:
#   RowNumber AnimalName AnimalGender AnimalBirthMonth  \
# 0   122,152    CHARRIE            F         8/1/2007
# 1   122,153      CHICO            M         7/1/2011
# 2   122,154       HUGO            M         7/1/2008
# 3   122,155        IKE            M         1/1/2007
# 4   122,156      JACKI            F         2/1/2008
#
#                               BreedName    Borough  ZipCode  \
# 0                               Unknown  Manhattan  10029.0
# 1                               Unknown   Brooklyn  11201.0
# 2                      Brussels Griffon     Queens  11375.0
# 3  American Pit Bull Mix / Pit Bull Mix   Brooklyn  11221.0
# 4                    Miniature Pinscher     Queens  11415.0
#
#    CommunityDistrict  CensusTract2010   NTA  CityCouncilDistrict  \
# 0              111.0            164.0  MN33                  8.0
# 1              306.0             69.0  BK38                 33.0
# 2              406.0            741.0  QN17                 29.0
# ...

# %%
dogs['ZipCode'].value_counts()
# Out:
# 10025.0    2610
# 10024.0    2118
# 10023.0    2050
# 10009.0    1880
# 10011.0    1875
# 10128.0    1873
# 11201.0    1800
# 10314.0    1795
# 11215.0    1785
# 10312.0    1650
# 10306.0    1440
# 10028.0    1436
# 10029.0    1408
# 10003.0    1336
# 11209.0    1331
# 10021.0    1284
# 11385.0    1262
# 10014.0    1259
# 10019.0    1250
# 11234.0    1145
# 10016.0    1106
# 11375.0    1019
# 11211.0    1007
# 10463.0     998
# 10002.0     994
# 10010.0     964
# 10036.0     960
# 11238.0     940
# 11206.0     929
# 10022.0     921
#            ...
# 7675.0        1
# 11002.0       1
# 11552.0       1
# 10968.0       1
# 10647.0       1
# 10533.0       1
# 11246.0       1
# 10550.0       1
# 10552.0       1
# 10570.0       1
# 8527.0        1
# 10577.0       1
# 10583.0       1
# 10591.0       1
# 10603.0       1
# 10606.0       1
# 10701.0       1
# 10950.0       1
# 10702.0       1
# 10703.0       1
# 11590.0       1
# 11569.0       1
# 34746.0       1
# 10803.0       1
# ...

# %%
dogs['AnimalGender'].value_counts()
# Out:
# M    58552
# F    49099
#          7
# Name: AnimalGender, dtype: int64
